# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import re
import seaborn as sns
from wordcloud import WordCloud
import nltk
nltk.download(['stopwords','punkt','wordnet','omw-1.4','vader_lexicon'])
# %matplotlib inline
# Out:
# [nltk_data] Downloading package stopwords to /home/mohsen/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /home/mohsen/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /home/mohsen/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /home/mohsen/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /home/mohsen/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %%
def preprocess_text(text):
    tokenized_document = nltk.tokenize.RegexpTokenizer('[a-zA-Z0-9\']+') 
    cleaned_tokens = [word.lower() for word in tokenized_document if word.lower() not in stop_words]
    stemmed_text = [nltk.stem.PorterStemmer().stem(word) for word in cleaned_tokens]
    return stemmed_text

# %%
data = pd.read_csv("tourist_accommodation_reviews.csv")
data.head()
# Out:
#             ID               Review Date Location  \
# 0  rn579778340      Reviewed 1 week ago     Kathu
# 1  rn576350875     Reviewed 3 weeks ago     Kathu
# 2  rn574921678     Reviewed 4 weeks ago     Kathu
# 3  rn572905503  Reviewed April 12, 2018     Kathu
# 4  rn572364712  Reviewed April 10, 2018     Kathu
#
#            Hotel/Restaurant name  \
# 0  Thong Dee The Kathu Brasserie
# 1  Thong Dee The Kathu Brasserie
# 2  Thong Dee The Kathu Brasserie
# 3  Thong Dee The Kathu Brasserie
# 4  Thong Dee The Kathu Brasserie
#
#                                               Review
# 0  Just been for sunday roast lamb and beef truly...
# 1  Quietly set off the main road, nice atmosphere...
# 2  I made a reservation for a birthday two days i...
# 3  We visit here regularly and never fail to be i...
# 4  Visited this wonderful place on my travels and...

# %%
data.describe()
# Out:
#                  ID           Review Date Location Hotel/Restaurant name  \
# count         53644                 53644    53644                 53644
# unique        49944                  2344       25                   537
# top     rn564592095  Reviewed 1 week ago    Patong              Da Mario
# freq             10                   616    16403                   279
#
#                                                    Review
# count                                               53644
# unique                                              49938
# top     I have been to this restaurant several times f...
# freq                                                   10

# %%
hotel_names = data['Hotel/Restaurant name'].unique()
hotel_names
# Out:
# array(['Thong Dee The Kathu Brasserie',
#        'Odysseus Greek Organic Restaurant', 'Green Tamarind Kitchen',
#        'Dee Plee - Anantara Layan Phuket Resort', 'The Tavern',
#        'EAT. bar & grill', 'Surf and Turf by Soul Kitchen',
#        'Siam Supper Club', "Sam's Steaks and Grill",
#        'Istanbul Turkish Restaurant', 'The Corner Restaurant',
#        'Kataturk Turkish Restaurant', 'Sala Sawasdee Lobby Bar',
#        'The Palm Cuisine', 'Highway Curry Indian & Thai Cuisine',
#        'Tandoori Flames', 'Pad Thai Shop', 'Golden Paradise Restaurant',
#        'Mr.Coffee', 'Flavor Phuket', 'Baan Noy Restaurant',
#        'Ao Chalong Yacht Club Restaurant', "Naughty Nuri's Phuket",
#        'Surin Chill House', 'Natural Efe Macrobiotic World',
#        'Honeymoon Thai Restaurant by Kenya', 'O-OH Farm Ta-Eiad',
#        'Da Puccio Restaurant', 'Sizzle Rooftop Restaurant',
#        "Benny's American Bar & Grill", 'Climax on Bangla',
#        'Le Brooklyn Patong', 'La Dolce Vita Restaurant', 'Sabaijai Cafe',
#        'The Cove Phuket', 'i-Kroon Cafe', "Ann's Kitchen Bar and Grill",
#        'Salute Italian Restaurant', 'The Family Restaurant',
#        'Shameena Restaurant and Lounge', 'Rustic - Eatery & Bar',
#        'Red Duck Restaurant', 'Rossovivo Ristorante Italiano E Pizzeria',
#        'Austrian Garden Restaurant', 'Breeze at Cape Yamu',
#        'Trattoria Capri da Rico', 'Takieng Thai Restaurant',
#        'The Islander', 'Vista', 'Bampot Kitchen & Bar',
#        'The Blue Mango Bar and Grill', 'Curry Night Indian Restaurant',
#        'Nami', 'Kalika 76 Restaurant', 'Orange Restaurant',
#        'Cashew Nuts Food', 'La Gritta', 'OSOT',
#        'Sandwich Shoppe Cafe & Bar Patong Phuket',
#        'Halfway Inn (Restaurant)', 'Taste Bar & Grill', 'The Grill',
#        'Grill Bill', 'Pooh and Friends', 'Pomodoro Pizza Restaurant',
#        'En Vogue Restaurant', 'Pizzeria AGLI AMICI da Michele & Jimmy',
#        'Don Vito Trattoria', 'ICC Indian Curry Club', 'Chilli Kitchen',
#        "Rosco's Restaurant & Sports Bar", 'Burger House Kata Beach',
#        'Kook Restaurant', 'Palm Square',
#        'BYD Lofts Restaurant Bistro & Bar', 'Home Dining Cafe & Lounge',
#        'Tatonka', 'Soul Curry Restaurant and Bar',
#        'Kantok Restaurant at Burasari Resort', 'The Greek Tavern',
#        'Poo Nurntong Restaurant', 'Out of the Blue Bar',
#        'Vanilla Sky Bar & Gastro Pub - Cape Sienna - Phuket, Thailand',
#        'SILK Restaurant & Bar', 'Restaurant Royale Nam Tok',
#        'Autogrill Risto Bar Pizza', 'Kata On Fire Bar and Grill',
#        'The Beach Cuisine', 'EuroThai Restaurant', 'New York Burger Co.',
#        'O-OH Farm Suanluang', 'Marriott Cafe', 'Suay Restaurant',
#        'Bianconero da Tuveri Restaurant & Pizzeria', 'Sabai Corner',
#        'Bollywood Phuket Restaurant & Bar', 'No 9 2nd Restaurant',
#        'Eightfold Restaurant', 'Rock Salt', 'Pizzeria Da Moreno',
#        'A Spoonful of Sugar', 'Black Ginger', 'Kopitiam by Wilai',
#        'Live India Indian Restaurant', 'Kin Dee Restaurant',
#        'Riverside Restaurant', 'Red Chair Restaurant',
#        'Three Crowns Restaurant & Grill', 'Beach Bar',
#        'YamThai Restaurant', 'Golbasi', 'Ginja Taste', 'Two Chefs Patong',
#        'MaMa Jin Restaurant', 'Thai Smile 2', 'Restaurant Break Point',
#        'Madras Cafe 2 & Guest House', 'Sand Box Restaurant and Bar',
#        'Blue Manao', 'K-Hotel Restaurant and Beer Garden',
#        'Ging Restaurant', 'Schlusslicht', "JJ's Bar & Food",
#        'Curry Delight Indian Restaurant',
#        'Karlsson Restaurant & Steak House', "Maggie & Mario's Pizzeria",
#        'Hey Ha Bar & Restaurant', 'DeDos', 'Acqua Restaurant',
#        'Elephant Cafe by Tan', 'Arabia Restaurant', 'ELLA Bar & Bistro',
#        'Sun Beach Cafe', "Enjoy's Italian Bar & Restaurant",
#        'Oriental Spoon', 'Tantra', 'Restaurant at Lillo Island Resort',
#        'Churrasco Phuket Steakhouse', 'Bai Toey', 'Restaurant Georgia',
#        'Patong Corner Restaurant', 'The Place', 'Plum Prime Steakhouse',
#        'Sawasdee', 'Palm Seaside', 'Pure Vegan Heaven',
#        'Two Chefs - Karon Beach', 'Coast Beach Club & Bistro Phuket',
#        'The Sweet Restaurant', 'The 9th Floor restaurant',
#        "Mom Tri's Kitchen at Villa Royale", 'Mor Mu Dong',
#        'Cut Grill & Lounge', 'One Chun Cafe and Restaurant', '360 ° Bar',
#        'Ruen Thai, Patong', 'Tu Kab Khao Restaurant',
#        'Charm Thai Restaurant at Holiday Inn Resort', 'The Breakfast Hut',
#        'Madame Saab Ver', 'Cucina',
#        'Blue Horizon - Top Quality Thai Food',
#        'Leo & Mas Ristorante Italiano e Pizzeria',
#        'Sugar & Spice Restaurant at Dome Resort', 'Sabai Sabai',
#        'New International Cafe & Bar', 'Pesto Restaurant',
#        'Kampong Kata Hill', 'Baan Mai', "Fatty's",
#        "Hakan's Bar & Restaurant", 'Little Tiger',
#        'Bush Garden Kamala<U+200B>',
#        'The Kitchen Restaurant Kata Beach & Thai Cooking Class',
#        'Chai Thaifood Restaurant', 'Sea Breeze', 'Le Celtique',
#        'Kabuki Japanese Cuisine Theatre', 'Little Paris', 'Red Corner',
#        'Blue Elephant Phuket', 'Song Pee Nong 2',
#        "Nok and Jo's Restaurant", 'Tree Top Restaurant and Bar',
#        "Rawai View Cafe' & Bar", 'Eleven Two & Co.',
#        'Two Chefs Kata Center', '44 Thaikitchen "KATA FOOD COURT"',
#        'Sabai Beach Restaurant', 'La Gaetana', 'Les Diables',
#        'Moo Restaurant', 'Horn Grill Steak and Seafood', 'Sala Mexicali',
#        'WAI thai', 'Hard Rock Cafe Phuket', 'CatFish Cafe',
#        'Baan Rim Pa Kalim', 'The Bua Restaurant', 'Shakers',
#        'Royal Tandoor', 'The Oceanfront Restaurant and Bar at Kata Rocks',
#        'Peony Cafe & Restaurant', 'Salsa Mexicana',
#        "Sultan's Grill Authentic Turkish & Indian Cuisine",
#        'Sunset Restaurant', 'Two Chefs Kata Beach', 'Kwong Shop Seafood',
#        'La Sala - Anantara Mai Khao Phuket Villas', 'Leonardo Davinci',
#        'Rider Cafe', 'SALA Phuket Restaurant', 'The Boathouse Restaurant',
#        'Siam Deli', 'Briley Chicken Rice',
#        "Phen's Restaurant Bar & Coffee", 'Tunk-Ka Cafe', 'Madras Cafe',
#        'Il Tagliere da Massimo', 'Napoli Ristorante Pizzeria',
#        'Kokosnuss', 'Karlssons Restaurant Patong', 'Papaya', 'We Cafe',
#        'Sweet and Sour', 'Yorkshire Hotel Restaurant',
#        'Mamma Mia Grill & Restaurant Bangtao',
#        'Karon Cafe Steakhouse & Thai Cuisine', 'No.6 Restaurant',
#        'Gallery Cafe by Pinky', 'On The Rocks - Marina Phuket Resort',
#        'Siam Smile Wine & Restaurant', 'White Orchid',
#        'Home Kitchen, Bar & Bed', 'Oiy Restaurant', 'Linda Seafood',
#        'HQ Beach Lounge', 'Laem Hin Seafood', 'Terrazzo Ristorante Bar',
#        'Smile Bar', 'Ying Restaurant',
#        'Sea Almond Chilled Restaurant & Bar', 'Bella Vista Restaurant',
#        '+39 Italian Street Food', 'O-Oh Farm Karon', '2gether Restaurant',
#        'Southern Fried Rice', 'Bamboo Bar', 'Catch Beach Club',
#        'China Inn Cafe', 'Yo Green Restaurant', 'Audy Restaurant',
#        'Cafe Siam Breakfast Cafe', 'THE DECK', 'Crust', 'Bocconcino',
#        'Sunset Bar', 'Sea Fire Salt - Anantara Mai Khao Phuket Villas',
#        'Butterfly Bistro', 'DaVinci Restaurant', 'No 9 Restaurant',
#        'Pum Thai Restaurant', 'Baba Soul Food', 'Restaurant Treffpunkt',
#        'The Bistro', 'Baan Ra Tree Restaurant',
#        'Legends Sports Bar & Grill', 'Lee Pizzeria & Restaurant',
#        "Nicky's Handlebar", 'You and Me Patong', 'D Restaurant',
#        'Badsha Indian Food', 'The Beach Restaurant on the beach',
#        'Kata Villa Restaurant', 'Veranda', 'Eurasian Restaurant',
#        'Sala Bua Restaurant', 'Sawasdee Thai Cuisine', 'Song Pee Nong',
#        'Lemongrass Restaurant', 'La Capannina da Mario', 'Panwa House',
#        'Raya Thai Cuisine', 'Rugantino', 'Bubbles Restaurant',
#        'Harrys Steakhouse & Hotel', 'Happy Days', 'S&G Family Restaurant',
#        'Blue Wave Restaurant', 'Pasha Kebab', 'Da Mario',
#        'Red Tuna Restaurant Phuket',
#        'Wine Connection Deli & Bistro - Jungceylon, Patong Beach',
#        'Wine Connection Bar & Grill - Kata Beach',
#        'Tawai Thai Restaurant', 'Sweet Dream Restaurant',
#        "Louis' Kitchen", 'Natural Restaurant', 'Wok',
#        'Sea Hag Restaurant', 'Red Snapper', 'The Drunken Leprechaun',
#        'Rum Jungle', "Don's Bar B Q", 'Pizzeria Hut 1',
#        'Da Maurizio Beach Side', 'The Coffee Club - The Turtle Village',
#        'Delish Cafe', "Full Moon Brewworks - Microbrewery & Lobs n' Roll",
#        "Joe's Downstairs", 'Baan Rim Pa Patong',
#        'Kan Eang@Pier Restaurant', 'Red Chopsticks', 'Bodega & Grill',
#        'Ska Bar', 'Pond Restaurant', "Metzo's Bistro",
#        'Mando Restaurant & Steakhouse', 'The Frying Kiwi Eatery',
#        'Ohlala', 'Mamma Mia Grill & Restaurant Kamala', 'Black Cat',
#        'Atsumi Raw Cafe', 'Bamboo Kitchen',
#        'Nanai Steak House and Thai Food', 'Mookdee Seafood',
#        'Macarona - European Cuisine & Pizzeria', 'Red Onion',
#        'Mee Ton Poe', 'Thai Thai Restaurant', 'White Box Phuket',
#        'Pan Yaah Thai Restaurant',
#        'COCONUT Bar & Restaurant - Rawai Beach', 'Portofino',
#        'Kaab Gluay', 'Aussie Pub Kamala', 'Bellini', "Pim's Place",
#        'Chez Nicolas', 'KEE Sky Lounge & Restaurant',
#        'La Carbonara Restaurant Pizzeria', 'Dee-Lish Bar & Restaurant',
#        'Oasis Bar', 'Ma Ma Nang Restaurant', 'Bill Bentley Pub',
#        'Mamasita Mexican', 'Chez Bernard', 'Irish Times Pub',
#        'The Ship Inn', '3 Spices Restaurant',
#        'Saffron at Banyan Tree Phuket', 'Singh Seafood Restaurant',
#        'Doo Dee', "Angus O'Tool's Irish Pub", 'Coral Restaurant', 'Flame',
#        'Andaman Grill', 'Capri Noi Restaurant',
#        'Portofino Ristrorante &Pizzeria', 'Coyote', 'Ann Restaurant',
#        'Bucintoro Pizzeria-Ristorante',
#        'Wine Connection Bistro - Banana Walk', 'Mint',
#        'Roma Ristorante & Pizzeria Da Mauro', 'Nikitas Beach Restaurant',
#        'Sugar Cane Restaurant', 'Uptown Restaurant', 'Pan Bistro',
#        'Baan Chom View', 'Cafe de Bangtao', 'Archee Restaurant',
#        'Laimai Courtyard Restaurant and Bar', 'Dang Restaurant',
#        'Elephant No.9 Restaurant', "Molly's Tavern", 'Enjoy Restaurant',
#        'Sansabai restaurant', 'The Green Gourmet', 'Mama Seafood',
#        'P.S. Hotel', 'Baia Del Sole', 'The Orchid Garden',
#        'Hooters Phuket', 'Salaloy Seafood', 'Shah Baba Indian Restaurant',
#        'Red Chopsticks At Patong', 'Mr Kobis', 'Amalfi', 'Anchor Inn',
#        'Tony Seafood Restaurant', 'Lucky 13 Sandwich Rawai',
#        'Buffalo Steak House - Karon Beach', 'Kan Eang 2',
#        "Salvatore's restaurant", 'Boulangerie Chez Nous',
#        'Mai Khao Seafood Local Restaurant',
#        'Trattoria pizzeria Cosa Nostra Delivery', "Norbu's Steakhouse",
#        'Kata B-B-Q', 'Lobster & Prawn Restaurant', 'Cafe Java',
#        'Urban food', 'Sabai Beach', 'Tiger Bar', 'Dibuk restaurant',
#        'Indian Delight Restaurant', 'El Gaucho Steakhouse', 'Green Mango',
#        'Bon Island Restaurant', "Danny's Place Kamala",
#        'Fork & Spoon Restaurant', 'East Restaurant', 'Khun Pha',
#        'Trattoria del Buongustaio',
#        'Deepavali Indian Restaurant - Bangtao Place',
#        'Food Court at Banzaan Fresh Market', 'Baan Kalim',
#        'Tokyo Japanese Restaurant',
#        'Chomtalay restaurant at Mandarava Resort and Spa',
#        'Khon Kaen Buffet BBQ', 'Kitchen Bistro Patong',
#        'The Pizza Company', 'Flip Side', 'Cafe del Mar Phuket',
#        'H.C. Andersen - Family Restaurant', 'Cafe 101 Bar & Restaurant',
#        'Spice House', 'Tom Yam Goong Restaurant Cherngtalay Phuket',
#        'Vitaporn', "Bob's Restaurant & Bar", 'Divino Tapas Restaurant',
#        'Top Of The Reef at Cape Panwa Hotel', 'Green Leaf Restaurant',
#        'The Siam Mumbai', 'Dino Park', 'Restaurant Mama Kata (Seafood)',
#        'The Crab House', 'Restaurant La Croisette', 'Sole Mio',
#        'Naiyang Park Restaurant', 'Som Restaurant',
#        'Belgian Beer Cafe Graceland', "9' Sea Breeze",
#        'MK Gold Restaurant', 'Ken Restaurant',
#        'Khaorang Breeze Restaurant', 'Mare Italian Restaurant',
#        'Thanoon Seafood', 'James & Joyce Irish Pub',
#        'SushiBox - Jungceylon', 'Modena', 'Il Cappero', 'After Beach Bar',
#        'The Cook', 'Skye Lake Club - Laguna, Phuket',
#        'Fuji Japanese Restaurant - Central Festival Phuket',
#        'The Sandwich Club', 'Da Mario Karon', 'Subparod Restaurant',
#        'D Wine Italian Bistro & Wine Bar',
#        'Fuji Japanese Restaurant - Jungceylon Patong',
#        'Royal India Restaurant Patong', 'Lucky 13 Sandwich Patong',
#        'No. 24 Bar & Restaurant', 'Kusuma Seafood',
#        'Wine Connection Deli & Bistro - Chalong, Phuket',
#        'Buffalo Steak House - Kata Plaza', 'Albatross Cafe',
#        'Chekhoff Restaurant and Bar', 'PaPa Restaurant',
#        'Surin Bay Inn Restaurant', 'B-Hive Gallery, Bar and Restaurant',
#        'Heaven', 'Brasserie Phuket', 'Kata Country House Restaurant',
#        'Wine Connection Deli & Bistro - Central Phuket',
#        'Food Market Kata', 'The Kitchen', 'Shabushi - Shabu Shabu Buffet',
#        'Baan Sailom Restaurant', 'Ship Inn Bar & Restaurant',
#        'Ristorante Pizzeria Zafferano', 'Kohinoor 2', 'Sorrento pizzeria',
#        'Cairo Restaurant', 'Navrang Mahal',
#        'La Piazzetta di Capri Patong', 'Kazu Patong Phuket',
#        "Uncle Nan's Italian Restaurant", 'Baluchi Restaurant',
#        'Bondi Aussie Bar & Grill Phuket', 'Mali Chic Restaurant',
#        'Food Market Restaurant', 'Capri Restaurant & Bar',
#        'Outdoor Restaurant', 'Jaowpraya', 'The Green Man Pub',
#        'Tandoor Phuket Indian', '99 Seafood', 'Spoon Cafe',
#        'Toto Italian Restaurant', "Natalie's Restaurant", 'Pinto',
#        'Salt & Pepper Restaurant Steakhouse Pizzeria', 'Savoy Patong',
#        'The Port', 'Jao Jong Seafood', 'Savoey Restaurant', 'Up Seafood',
#        'The Secret Cliff Resort & Restaurant', 'Coconut-garden',
#        'Mama Restaurant - Karon Beach', 'Tiger Inn Restaurant',
#        'The Red Tablecloth', 'Malila Restaurant', 'Baoli', 'Le Siam',
#        'Kwality Indian Restaurant', 'La Boucherie - Chalong', 'Jeffer',
#        "Mr Good's Seafood", 'The Orchids Restaurant', 'Phuket La Ca Sa',
#        'Karon Seafood', 'Dada Yura Restaurant', 'Patong Seafood',
#        "Rayaan's Oriental Restaurant", 'Thai Express - Turtle Village',
#        'Tropica Restaurant & Beer Garden',
#        'Mali Seafood Restaurant & Bar', 'Chaba', 'La Casa',
#        'Khan Baba phuket', 'Pizza Hut - Jungceylon',
#        'Ali Baba Restaurant', 'Bite in'], dtype=object)

# %%
np.random.seed(30)
randoms = np.random.randint(30, size=(1,30))
selected_hotels = np.array([])
for i in randoms:
    selected_hotels = np.append(selected_hotels, hotel_names[i])
print(selected_hotels)
len(selected_hotels)
# Out:
# ['EAT. bar & grill' 'EAT. bar & grill' 'The Palm Cuisine'
#  'The Palm Cuisine' 'Baan Noy Restaurant' 'Sala Sawasdee Lobby Bar'
#  'Surin Chill House' 'Green Tamarind Kitchen'
#  'Ao Chalong Yacht Club Restaurant' 'Da Puccio Restaurant'
#  'Golden Paradise Restaurant' 'Highway Curry Indian & Thai Cuisine'
#  'Dee Plee - Anantara Layan Phuket Resort' 'Istanbul Turkish Restaurant'
#  'Siam Supper Club' 'Surin Chill House'
#  'Odysseus Greek Organic Restaurant' 'Golden Paradise Restaurant'
#  'The Palm Cuisine' "Benny's American Bar & Grill"
#  'Dee Plee - Anantara Layan Phuket Resort' 'Mr.Coffee' 'Mr.Coffee'
#  'Baan Noy Restaurant' 'Baan Noy Restaurant'
#  'Surf and Turf by Soul Kitchen' 'Sala Sawasdee Lobby Bar' 'Pad Thai Shop'
#  'Surf and Turf by Soul Kitchen' 'Da Puccio Restaurant']
# 30

# %%
selected_hotels[0]
# Out:
# 'EAT. bar & grill'

# %%
dept_emp_num =  data.groupby('Hotel/Restaurant name')['Hotel/Restaurant name'].count()
print(dept_emp_num)
# Out:
# Hotel/Restaurant name
# +39 Italian Street Food              91
# 2gether Restaurant                  100
# 3 Spices Restaurant                 100
# 360 ° Bar                           100
# 44 Thaikitchen "KATA FOOD COURT"     93
#                                    ...
# Ying Restaurant                     100
# Yo Green Restaurant                 100
# Yorkshire Hotel Restaurant          100
# You and Me Patong                   100
# i-Kroon Cafe                        100
# Name: Hotel/Restaurant name, Length: 537, dtype: int64

# %%
df1 = data[data['Hotel/Restaurant name'] == selected_hotels[0]]
df1
# Out:
#               ID                  Review Date      Location  \
# 493  rn581330980          Reviewed yesterday    Karon Beach
# 494  rn580837511         Reviewed 3 days ago    Karon Beach
# 495  rn580780572         Reviewed 3 days ago    Karon Beach
# 496  rn580641423         Reviewed 4 days ago    Karon Beach
# 497  rn576233218        Reviewed 3 weeks ago    Karon Beach
# ..           ...                          ...           ...
# 588  rn550604314    Reviewed January 1, 2018    Karon Beach
# 589  rn550351113  Reviewed December 30, 2017    Karon Beach
# 590  rn550312641  Reviewed December 30, 2017    Karon Beach
# 591  rn549920709  Reviewed December 29, 2017    Karon Beach
# 592  rn549884891  Reviewed December 28, 2017    Karon Beach
#
#     Hotel/Restaurant name                                             Review
# 493      EAT. bar & grill  I was excited to finally come here and try the...
# 494      EAT. bar & grill  This place prides it’s self on only serving th...
# 495      EAT. bar & grill  99 Thai Bhat for a simply delicious mojito! I ...
# 496      EAT. bar & grill  Very trendy place to have your a meal Staff we...
# 497      EAT. bar & grill  Best food, starter start with bruschetta and f...
# ..                    ...                                                ...
# 588      EAT. bar & grill  We saved the best for last! After a week in Ka...
# 589      EAT. bar & grill  We went to Eat with our 10-year-old, and loved...
# 590      EAT. bar & grill  My wife and I phoned from home in England to b...
# 591      EAT. bar & grill  Most amazing Chateaubriand ever tasted!Being f...
# 592      EAT. bar & grill  Good place. Its a steak house restaurant. Ufor...
#
# [100 rows x 5 columns]

# %%
sentiment = SentimentIntensityAnalyzer()

# %%
print(sentiment.polarity_scores('This movie is great!'))
print(sentiment.polarity_scores('This movie is not great!'))
# Out:
# {'neg': 0.0, 'neu': 0.406, 'pos': 0.594, 'compound': 0.6588}
# {'neg': 0.473, 'neu': 0.527, 'pos': 0.0, 'compound': -0.5553}
